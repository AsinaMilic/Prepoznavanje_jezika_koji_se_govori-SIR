# %%
# !git clone https://github.com/AsinaMilic/Spoken-Language-Identification--SLID----Simple.git
# %cd Spoken-Language-Identification--SLID----Simple


from google.colab import drive
drive.mount('/content/drive')

# !mkdir -p data/processed
# !mkdir -p data/raw
# !unzip -q /content/drive/MyDrive/language-recognition/processed_data.zip -d data/processed


# !pip install -q librosa soundfile scikit-learn pandas matplotlib seaborn rich tqdm pyyaml
# !python train.py --load-dataset --processed-dir data/processed
# Out:
# Cloning into 'Spoken-Language-Identification--SLID----Simple'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 60 (delta 17), reused 59 (delta 16), pack-reused 0 (from 0)
# Receiving objects: 100% (60/60), 84.52 KiB | 6.04 MiB/s, done.
# Resolving deltas: 100% (17/17), done.
# /content/Spoken-Language-Identification--SLID----Simple
# Mounted at /content/drive
# 2025-10-23 11:09:58.464288: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761217798.497907     681 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...
